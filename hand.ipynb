# %% [markdown]
# -pip install mediapipe==0.10.9 (Supported in all machines)

# %%
import cv2
import mediapipe as mp

# %% [markdown]
# ✔ MediaPipe 0.10.32
#
# ✔ NumPy 2.4.3
#
# ✔ SciPy upgraded to 1.17.1 (supports NumPy 2.x)
#
# ✔ OpenCV installed
#
# ✔ TensorFlow installed
#
# ✔ Python 3.12 compatible stack

# %%
# Handlamarks detection
# ------------------------

mphands=mp.solutions.hands #hand landmarks
# solutions is module which contains all landmarks
mp_drawing=mp.solutions.drawing_utils
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Handlamarks detection
#       2 # ------------------------
# ----> 4 mphands=mp.solutions.hands #hand landmarks
#       5 # solutions is module which contains all landmarks
#       6 mp_drawing=mp.solutions.drawing_utils
#
# AttributeError: module 'mediapipe' has no attribute 'solutions'

# %%
# import Hands() class from submodule hands

mphands.
